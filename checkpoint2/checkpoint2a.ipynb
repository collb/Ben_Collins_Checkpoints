# %% [markdown]
# # Exercises

# %% [markdown]
# These exercises are a mix of Python and pandas/EDA practice. Most should be no more than a few lines of code!

# %%
# here is a Python list:

a = [1, 2, 3, 4, 5, 6]

# get a list containing the last 3 elements of a
a[-3:]
# reverse the list
for i in reversed(a):
    print (i)
# get a list where each entry in a is squared (so the new list is [1, 4, 9, 16, 25, 36])
for i in range(len(a)):
    print(a[i]*a[i])
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 1
# 4
# 9
# 16
# 25
# 36

# %%
# create a numpy array from this list
import numpy as np
b = np.array(a)

# %%
# find the mean of b
b.mean()
# Out:
# 3.5

# %%
# get a list where each entry in b is squared (so the new numpy array is [1, 4, 9, 16, 25, 36])
# use a different (numpy-specific) approach
b = np.square(b)
print(b)
# Out:
# [ 1  4  9 16 25 36]

# %%
# change b from a length-6 list to a 2x3 matrix
b = b.reshape(2,3)

# %%
# find the mean value of each row
b.mean()
# Out:
# 15.166666666666666

# %%
# find the mean value of each column
b.mean(axis=0)
# Out:
# array([ 8.5, 14.5, 22.5])

# %%
# find the third column of b
[row[2] for row in b]
# Out:
# [9, 36]

# %%
# load in the "starbucks_clean.csv" dataset
import pandas as pd
df = pd.read_csv('../data/starbucks_clean.csv')
df
# Out:
#      Unnamed: 0       beverage_category                             beverage  \
# 0             0                  coffee                         brewedcoffee
# 1             1                  coffee                         brewedcoffee
# 2             2                  coffee                         brewedcoffee
# 3             3                  coffee                         brewedcoffee
# 4             4   classicespressodrinks                            cafflatte
# ..          ...                     ...                                  ...
# 237         237  frappuccinoblendedcrme  strawberriescrmewithoutwhippedcream
# 238         238  frappuccinoblendedcrme       vanillabeanwithoutwhippedcream
# 239         239  frappuccinoblendedcrme       vanillabeanwithoutwhippedcream
# 240         240  frappuccinoblendedcrme       vanillabeanwithoutwhippedcream
# 241         241  frappuccinoblendedcrme       vanillabeanwithoutwhippedcream
#
# ...

# %%
# this is nutritional info for starbucks items
# let's see if we can answer some questions

# what is the average # calories across all items?
df.calories.mean()
# Out:
# 193.87190082644628

# %%
# how many different categories of beverages are there?
a = ((df['beverage_category'].unique()))

# %%
# what is the average # calories for each beverage category?
a = ((df['beverage_category'].unique()))
for i in range(len(a)):
    print(df[df['beverage_category'] == a[i]]['calories'].mean())
    print(a[i])
# Out:
# 4.25
# coffee
#
# 140.17241379310346
# classicespressodrinks
#
# 250.0
# signatureespressodrinks
#
# 177.30769230769232
# tazoteadrinks
#
# 114.44444444444444
# shakenicedbeverages
#
# 282.22222222222223
# smoothies
#
# 276.94444444444446
# frappuccinoblendedcoffee
#
# 162.5
# frappuccinolightblendedcoffee
#
# 233.07692307692307
# frappuccinoblendedcrme

# %%
# what beverage preparation includes the most sugar on average?
df = pd.read_csv('../data/starbucks_clean.csv')
a = ((df['beverage_prep'].unique()))
df['beverage_prep']
for i in range(len(a)):
    print(df[df['beverage_prep'] == a[i]][ 'sugars '].mean())
    print(a[i])
    print()
# Out:
# 8.25
# Short
#
# 14.714285714285714
# Tall
#
# 20.0
# Grande
#
# 27.714285714285715
# Venti
#
# 17.0
# Short Nonfat Milk
#
# 30.98
# 2% Milk
#
# 31.848484848484848
# Soymilk
#
# 28.52173913043478
# Tall Nonfat Milk
#
# 38.61538461538461
# Grande Nonfat Milk
#
# 50.04545454545455
# Venti Nonfat Milk
#
# 0.0
# Solo
#
# 0.0
# Doppio
#
# 55.6875
# Whole Milk

# %%
# what is the average % daily value calcium content for each beverage?
df = pd.read_csv('../data/starbucks_clean.csv')
a = ((df['beverage'].unique()))
for i in range(len(a)):
    print(df[df['beverage'] == a[i]]['calcium '].mean())
    print(a[i])
    print()
# Out:
# 0.5
# brewedcoffee
#
# 35.0
# cafflatte
#
# 30.0
# caffmochawithoutwhippedcream
#
# 32.916666666666664
# vanillalatteorotherflavouredlatte
#
# 1.5
# caffamericano
#
# 22.5
# cappuccino
#
# 0.0
# espresso
#
# 33.75
# skinnylatteanyflavour
#
# 28.333333333333332
# caramelmacchiato
#
# 41.25
# whitechocolatemochawithoutwhippedcream
#
# 35.0
# hotchocolatewithoutwhippedcream
#
# 0.0
# caramelapplespicewithoutwhippedcream
#
# 0.0
# tazotea
#
# 21.666666666666668
# tazochaitealatte
#
# 39.166666666666664
# tazogreentealatte
#
# 20.833333333333332
# tazofullleaftealatte
#
# 20.833333333333332
# tazofullleafredtealattevanillarooibos
#
# 0.0
# icedbrewedcoffeewithclassicsyrup
#
# 8.0
# icedbrewedcoffeewithmilkclassicsyrup
#
# 0.0
# shakenicedtazoteawithclassicsyrup
#
# 0.0
# shakenicedtazotealemonadewithclassicsyrup
#
# 20.0
# bananachocolatesmoothie
#
# 10.0
# orangemangobananasmoothie
#
# 10.0
# strawberrybananasmoothie
#
# 12.333333333333334
# coffee
#
# 12.0
# mochawithoutwhippedcream
#
# ...

# %%
# It's bulking season. What drink should Naitian get so that he maximizes protein but minimizes calories?
# (you can use more than one line for this one)
# there are multiple valid approaches you can take for this (with different answers)
# I know that you want more calories for bulking season but whatever this is MDST, not Michigan Muscle Club okay
df = pd.read_csv('../data/starbucks_clean.csv')
a = ((df['beverage'].unique()))
for i in range(len(a)):
    print(df[df['beverage'] == a[i]]['protein '].mean() / df[df['beverage'] == a[i]]['calories'].mean(), 'protein/cal')
    print(a[i])
    print()
# Out:
# 0.16470588235294117 protein/cal
# brewedcoffee
#
# 0.07485029940119761 protein/cal
# cafflatte
#
# 0.05277777777777778 protein/cal
# caffmochawithoutwhippedcream
#
# 0.04978723404255319 protein/cal
# vanillalatteorotherflavouredlatte
#
# 0.061818181818181814 protein/cal
# caffamericano
#
# 0.07592592592592592 protein/cal
# cappuccino
#
# 0.09333333333333332 protein/cal
# espresso
#
# 0.09545454545454546 protein/cal
# skinnylatteanyflavour
#
# 0.047511312217194575 protein/cal
# caramelmacchiato
#
# 0.03787878787878788 protein/cal
# whitechocolatemochawithoutwhippedcream
#
# 0.04929577464788732 protein/cal
# hotchocolatewithoutwhippedcream
#
# 0.0 protein/cal
# caramelapplespicewithoutwhippedcream
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-85-a6b4508c4011> in <module>
#       6 a = ((df['beverage'].unique()))
#       7 for i in range(len(a)):
# ...

# %%
# plot the distribution of the number of calories in drinks using matplotlib
import matplotlib.pyplot as plt
df.groupby("beverage")["calories"].hist()
# Out:
# beverage
# bananachocolatesmoothie                      AxesSubplot(0.125,0.125;0.775x0.755)
# brewedcoffee                                 AxesSubplot(0.125,0.125;0.775x0.755)
# caffamericano                                AxesSubplot(0.125,0.125;0.775x0.755)
# cafflatte                                    AxesSubplot(0.125,0.125;0.775x0.755)
# caffmochawithoutwhippedcream                 AxesSubplot(0.125,0.125;0.775x0.755)
# cappuccino                                   AxesSubplot(0.125,0.125;0.775x0.755)
# caramel                                      AxesSubplot(0.125,0.125;0.775x0.755)
# caramelapplespicewithoutwhippedcream         AxesSubplot(0.125,0.125;0.775x0.755)
# caramelmacchiato                             AxesSubplot(0.125,0.125;0.775x0.755)
# caramelwithoutwhippedcream                   AxesSubplot(0.125,0.125;0.775x0.755)
# coffee                                       AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
# plot the same distribution using seaborn. what about a density plot instead?
import seaborn as sns
sns.set()
plt.figure(figsize=(15, 15))
sns.scatterplot(data=df, x="calories", y="protein ", hue="beverage")
# Out:
# <AxesSubplot:xlabel='calories', ylabel='protein '>

# %%
# plot calories against total fat using seaborn
plt.figure(figsize=(15, 15))
sns.scatterplot(data=df, x="calories", y="total fat ", hue="beverage")
# Out:
# <AxesSubplot:xlabel='calories', ylabel='total fat '>

# %%
# plot the distribution of calories in Short, Tall, Grande, and Venti drinks
# (you can use multiple lines for this)
# twist: you should also include the Nonfat Milk drinks that also have an associated size.

# you can decide how you want to visualize this. Colors? Small multiples? Density vs histogram?
# the starbucks is your oyster.

df = pd.read_csv('../data/starbucks_clean.csv')
for i in range(len(df['beverage_prep'])):
    if(df.at[i, 'beverage_prep'].find('Grande')+1):
        df.at[i, 'beverage_prep'] = 'Grande'
    elif(df.at[i, 'beverage_prep'].find('Venti')+1):
        df.at[i, 'beverage_prep'] = 'Venti'
    elif(df.at[i, 'beverage_prep'].find('Tall')+1):
        df.at[i, 'beverage_prep'] = 'Tall'
    elif(df.at[i, 'beverage_prep'].find('Short')+1):
        df.at[i, 'beverage_prep'] = 'Short'
plt.figure(figsize=(10,10))
a = ['Grande', 'Venti', 'Tall', 'Short']
df = df[(df['beverage_prep'] == 'Tall') | (df['beverage_prep'] == 'Short') | (df['beverage_prep'] == 'Venti') | (df['beverage_prep'] == 'Grande')]
df.groupby("beverage_prep")["calories"].hist()
# Out:
# beverage_prep
# Grande    AxesSubplot(0.125,0.125;0.775x0.755)
# Short     AxesSubplot(0.125,0.125;0.775x0.755)
# Tall      AxesSubplot(0.125,0.125;0.775x0.755)
# Venti     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: calories, dtype: object
