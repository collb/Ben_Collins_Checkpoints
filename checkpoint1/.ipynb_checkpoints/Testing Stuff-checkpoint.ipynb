# %%
# %load_ext autoreload
# %autoreload 2
import checkpoint1b
import pandas as pd
df = pd.read_csv('../data/starbucks.csv')
col = 'Vitamin A (% DV)'
j = 1
a = int(df[col][j].split('%')[0])
df = a
df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0

# %%
# %autoreload 2
import checkpoint1b
import pandas as pd
df = pd.read_csv('../data/starbucks.csv')
col = 'Vitamin A (% DV)'
df = checkpoint1b.remove_percents(df,col)
df = checkpoint1b.fill_zero_iron(df)
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
A = float("nan")
B = 1
if(B==A):
    print("It works")

# %%
# %autoreload 2
import checkpoint1b
import pandas as pd
df = pd.read_csv('../data/starbucks.csv')
df = checkpoint1b.fill_zero_iron(df)
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
# %autoreload 2
import checkpoint1b
import pandas as pd

df = pd.read_csv('../data/starbucks.csv')
hehe = checkpoint1b.give_back_one(df)
hehe
# Out:
# 2

# %%
# %autoreload 2
import checkpoint1b
import pandas as pd
df = pd.read_csv('../data/starbucks.csv')
col = 'Vitamin A (% DV)'
df = checkpoint1b.fill_zero_iron(df)
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
A = float("nan")
A == A
# Out:
# False

# %%
# %autoreload 2
import checkpoint1b
import pandas as pd
df = pd.read_csv('../data/starbucks.csv')
col = 'Caffeine (mg)'
df = checkpoint1b.fix_caffeine(df)
df
# Out:
# 19605 89.52054794520548
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
A = "A ManaA KinA!®èÉ"
B = A.casefold()
C = len(B)
# Out:
# 'a maaa kia!®èé'

# %%
ord("a")
# Out:
# 97

# %%
txt = "I like bananas"
x = txt.replace("bananas", "")
x
# Out:
# 'I like '

# %%
# %autoreload 2
import checkpoint1b
import pandas as pd
df = pd.read_csv('../data/starbucks.csv')
col = 'Beverage_category'
df = checkpoint1b.fix_strings(df, col)
df.sample(30)
# Out:
#                  Beverage_category  \
# 99         signatureespressodrinks
# 24           classicespressodrinks
# 228  frappuccinolightblendedcoffee
# 34           classicespressodrinks
# 214       frappuccinoblendedcoffee
# 104                  tazoteadrinks
# 230         frappuccinoblendedcrme
# 172                      smoothies
# 16           classicespressodrinks
# 119                  tazoteadrinks
# 218  frappuccinolightblendedcoffee
# 189       frappuccinoblendedcoffee
# 33           classicespressodrinks
# 101        signatureespressodrinks
# 21           classicespressodrinks
# 135                  tazoteadrinks
# 11           classicespressodrinks
# 224  frappuccinolightblendedcoffee
# 163            shakenicedbeverages
# 137                  tazoteadrinks
# 233         frappuccinoblendedcrme
# 113                  tazoteadrinks
# 98         signatureespressodrinks
# 139                  tazoteadrinks
# 74         signatureespressodrinks
# ...

# %%
remove = []
remove.append(1)
remove
# Out:
# [1]

# %%
        string = ("Classic Espresso Drinks").casefold()
        remove = []
        for j in range(len(string)):
            if(not((ord(string[j]) >= 97) and (ord(string[j]) <= 122))):
                remove.append(string[j])
        remove.reverse()
        for k in range(len(remove)):
            string = string.replace(remove[k],'')
            print(string)
# Out:
# [' ', ' ']
# classicespressodrinks
# classicespressodrinks
# [' ', ' ']

# %%
fruits = ['apple', 'banana', 'cherry']
fruits.append("orange")
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
# %autoreload 2
import checkpoint1b
import pandas as pd
df = pd.read_csv('../data/starbucks.csv')
df = checkpoint1b.standardize_names(df)
df
# Out:
#               beverage_category                                      beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
string = 'abcd'
try:
    string.index('(')
except (ValueError):
    print("Nothing")
# Out:
# Nothing

# %%
A = 12
B = 20
for i in range(B-1, A-1, -1):
    print(i)
# Out:
# 19
# 18
# 17
# 16
# 15
# 14
# 13
# 12

# %%
txt =  "Sodium (mg)"

x = txt.split("(")[0]

print(x)
# Out:
# Sodium

# %%
a = "6.00%"

b = int(float(a.replace('%','')))
b
# Out:
# 6
